# %% [markdown]
# # Kallisto pipeline
#
# The pipeline presented in this notebook will require the following:
#
# 1. __kallisto__ for alignment-free transcript abundance quantification
# 2. __multiQC__ to generate QC report and check if there are low quality samples to exclude from downstream analysis
# 3. __tximport__ to aggregate transcript counts and produce gene-level count matrices and normalizing offsets

# %%
#Imports required libraries
import os, IPython, re
import pandas as pd
pd.set_option('display.max_columns', 500)
import numpy as np
from functools import reduce
#Other imports 
import tools.progressbar as pg
import tools.utilities as utils

# %%
#Select sound for audio alerts
sound_file = 'tools/test.wav'

# %% [markdown]
# ## Quantify transcripts using kallisto
# * Download reference transcripts

# %%
# Create folders to store the reference genome
QUANTDIR= 'quant'
try:
    os.makedirs(QUANTDIR)
except FileExistsError:
    # directory already exists
    pass

# %%
#dowload transcript file
transcript_file = os.path.join(os.getcwd(),QUANTDIR,'gencode.v30.transcripts.fa.gz')
utils.download_ftp('ftp.ebi.ac.uk', 'pub/databases/gencode/Gencode_human/release_30/gencode.v30.transcripts.fa.gz', transcript_file)
# Out:
# /Users/jeagor/Documents/GitHub/RNAseq/pipelines/quant/gencode.v30.transcripts.fa.gz already downloaded

# %% [markdown]
# * Create Kallisto index https://pachterlab.github.io/kallisto/starting

# %%
transcript_index= os.path.join(os.getcwd(),QUANTDIR,'kallisto_gencode.v30_quasi_index')
if not os.path.exists(transcript_index):
    ## Create salmon index (make sure to have sufficient disk space and memory)
    utils.run_command(f'kallisto index -i {transcript_index} {transcript_file}')
    #sound alert when done
    IPython.display.Audio(sound_file, autoplay=True)
else:
    print(transcript_index, 'already created')
# Out:
# /Users/jeagor/Documents/GitHub/RNAseq/pipelines/quant/kallisto_gencode.v30_quasi_index already created

# %% [markdown]
# * quantify transcripts

# %%
#For SINGLE END libraries, you will need to know the average and standard deviation of the FRAGMENT length. These cannot be infered.
#If you do not have this information, use Salmon.
length = 100
std = 30

# %%
########## alignment-free transcript abundance quantification ##########
FASTQDIR = 'data/fastq'
OUTDIR = os.path.join(os.getcwd(),QUANTDIR,'kallisto_output')
single_samples = [f.split('.')[0] for f in os.listdir(FASTQDIR) if f.endswith('.sra.fastq.gz')]
paired_samples = [f.split('.')[0] for f in os.listdir(FASTQDIR) if f.endswith('.sra_1.fastq.gz')]

# %%
## Align and assemble single-end sequencing reads
for sample in pg.log_progress(single_samples):
    fastq = os.path.join(FASTQDIR,sample+'.sra.fastq.gz')
    output = os.path.join(OUTDIR,sample)
    if not os.path.exists(output):
        os.makedirs(output)
        print('Processing sample',sample)
        #If your reads are single end only you can run kallisto by specifying the --single flag,
        #however you must supply the length and standard deviation of the fragment length (not the read length).
        utils.run_command(f'kallisto quant -i {transcript_index} -o {output} -t {utils.N_CPU} --single -l {length} -s {std} {fastq}')


## Align and assemble paired-end sequencing reads
for sample in pg.log_progress(paired_samples):
    fastq1 = os.path.join(FASTQDIR,sample+'.sra_1.fastq.gz')
    fastq2 = os.path.join(FASTQDIR,sample+'.sra_2.fastq.gz')
    output = os.path.join(OUTDIR,sample)
    if not os.path.exists(output):
        os.makedirs(output)
        print('Processing sample',sample)
        utils.run_command(f'kallisto quant -i {transcript_index} -o {output} -t {utils.N_CPU} {fastq1} {fastq2}')

print('Transcript abundance quantification done')
#sound alert when done
IPython.display.Audio(sound_file, autoplay=True)
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=14)))
# Processing sample SRR6231076
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231076.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 7,877,339 reads, 6,549,068 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,077 rounds
#
# Processing sample SRR6231077
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231077.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 9,444,712 reads, 7,811,219 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,051 rounds
#
# Processing sample SRR6231078
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231078.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 6,979,362 reads, 5,982,621 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,075 rounds
#
# Processing sample SRR6231079
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231079.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 8,515,581 reads, 6,919,928 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,148 rounds
#
# Processing sample SRR6231080
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231080.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 8,927,960 reads, 7,522,532 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,118 rounds
#
# Processing sample SRR6231081
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231081.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 6,893,216 reads, 5,631,223 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,239 rounds
#
# Processing sample SRR6231082
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231082.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 8,406,129 reads, 7,226,777 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,105 rounds
#
# Processing sample SRR6231083
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231083.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 7,389,170 reads, 6,177,023 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,319 rounds
#
# Processing sample SRR6231084
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231084.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 5,669,618 reads, 4,605,749 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,158 rounds
#
# Processing sample SRR6231085
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231085.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 7,305,219 reads, 6,107,925 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,107 rounds
#
# Processing sample SRR6231086
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231086.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 8,610,087 reads, 6,957,478 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,153 rounds
#
# Processing sample SRR6231087
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231087.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 8,806,662 reads, 7,462,821 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,056 rounds
#
# Processing sample SRR6231088
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231088.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 9,431,997 reads, 7,992,569 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,249 rounds
#
# Processing sample SRR6231089
#
# [quant] fragment length distribution is truncated gaussian with mean = 100, sd = 30
# [index] k-mer length: 31
# [index] number of targets: 208,621
# [index] number of k-mers: 130,783,978
# [index] number of equivalence classes: 873,012
# [quant] running in single-end mode
# [quant] will process file 1: data/fastq/SRR6231089.sra.fastq.gz
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 9,033,611 reads, 7,652,936 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,110 rounds
# VBox(children=(HTML(value=''), IntProgress(value=0, max=0)))
# Transcript abundance quantification done
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## QC
# * Check the quality of the raw reads (fastq files) and %mapping (salmon) to check which samples need to be excluded

# %%
#We can examine the QC report generated by multiQC to evaluate the quality of the data
# !multiqc . -f --outdir data
IPython.display.IFrame('data/multiqc_report.html', width=800, height=350)
# Out:
# /Users/jeagor/anaconda3/envs/rnaseq/lib/python3.6/site-packages/multiqc/utils/config.py:45: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   configs = yaml.load(f)
# /Users/jeagor/anaconda3/envs/rnaseq/lib/python3.6/site-packages/multiqc/utils/config.py:51: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   sp = yaml.load(f)
# [INFO   ]         multiqc : This is MultiQC v1.7
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching '.'
# Searching 307 files..  [####################################]  100%
# [INFO   ]          salmon : Found 14 meta reports
# [INFO   ]          salmon : Found 14 fragment length distributions
# [INFO   ]        kallisto : Found 14 reports
# [INFO   ]          fastqc : Found 14 reports
# [INFO   ]         multiqc : Compressing plot data
# [WARNING]         multiqc : Deleting    : data/multiqc_report.html   (-f was specified)
# [WARNING]         multiqc : Deleting    : data/multiqc_data   (-f was specified)
# [INFO   ]         multiqc : Report      : data/multiqc_report.html
# [INFO   ]         multiqc : Data        : data/multiqc_data
# [INFO   ]         multiqc : MultiQC complete
#         <iframe
#             width="800"
#             height="350"
#             src="data/multiqc_report.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Here there did not seem to be adaptor contamination and base quality was good throughout the reads for all retained samples so we decided not to perform adaptor and quality trimmimg.

# %% [markdown]
# ## Aggregate transcripts TPM and counts by gene

# %% [markdown]
# ### Import and merge all quant files from kallisto's output

# %%
# %%time
quants = []
namelist = None
tx_number = None

#import all quant.sf files
samples = sorted([s for s in os.listdir(OUTDIR) if s.startswith('SRR')])
for sample in samples:
    file = os.path.join(OUTDIR,sample,'abundance.tsv')
    quant_df = pd.read_csv(file, sep=r'\t', engine='python')
    quant_df.rename(columns= {'est_counts':'counts', 'target_id':'IDs'}, inplace= True)
    #check all files have the same list of transcripts
    if namelist is None:
        namelist = quant_df['IDs'].values
    if not all(quant_df['IDs'].values == namelist):
        print(sample, 'has different transcript list')
    if tx_number is None:
        tx_number = len(quant_df)
    if len(quant_df) != tx_number:
        print(sample, 'has different transcript number')

    #drop length column as it won't be used
    quant_df.drop(['length', 'eff_length'], axis= 1, inplace= True)
    #add sample name to columns to facilitate merging
    quant_df.columns = [f'{col}_{sample}' if col != 'IDs' else col for col in quant_df.columns]
    quants += [quant_df]
# Out:
# CPU times: user 16.6 s, sys: 616 ms, total: 17.2 s
# Wall time: 17.3 s

# %%
# %%time
#merge all quant files
merged = reduce(lambda left,right: pd.merge(left,right, on='IDs', how='outer'), quants)
#sort columns alphabetically
merged = merged.reindex(['IDs'] + sorted(merged.columns[1:], key=lambda x: x.lower()), axis=1)
print(merged.shape)
merged.head()
# Out:
# (208621, 29)
# CPU times: user 2.43 s, sys: 462 ms, total: 2.89 s
# Wall time: 2.89 s

# %%
#split all IDs in Name
IDs = merged.IDs.str.split(pat='|', expand=True).drop([6,8], axis=1)
IDs.columns = ['Tx', 'Gene', 'ID2', 'ID3', 'ID4', 'ID5', 'Type']
IDs.head()
# Out:
#                   Tx               Gene                   ID2  \
# 0  ENST00000456328.2  ENSG00000223972.5  OTTHUMG00000000961.2
# 1  ENST00000450305.2  ENSG00000223972.5  OTTHUMG00000000961.2
# 2  ENST00000488147.1  ENSG00000227232.5  OTTHUMG00000000958.1
# 3  ENST00000619216.1  ENSG00000278267.1                     -
# 4  ENST00000473358.1  ENSG00000243485.5  OTTHUMG00000000959.2
#
#                     ID3              ID4          ID5  \
# 0  OTTHUMT00000362751.1      DDX11L1-202      DDX11L1
# 1  OTTHUMT00000002844.2      DDX11L1-201      DDX11L1
# 2  OTTHUMT00000002839.1       WASH7P-201       WASH7P
# 3                     -    MIR6859-1-201    MIR6859-1
# 4  OTTHUMT00000002840.1  MIR1302-2HG-202  MIR1302-2HG
#
#                                  Type
# 0                processed_transcript
# 1  transcribed_unprocessed_pseudogene
# 2              unprocessed_pseudogene
# 3                               miRNA
# 4                             lincRNA

# %%
tx_quant = IDs.merge(merged, left_index=True, right_index=True)
tx_quant.head()
# Out:
#                   Tx               Gene                   ID2  \
# 0  ENST00000456328.2  ENSG00000223972.5  OTTHUMG00000000961.2
# 1  ENST00000450305.2  ENSG00000223972.5  OTTHUMG00000000961.2
# 2  ENST00000488147.1  ENSG00000227232.5  OTTHUMG00000000958.1
# 3  ENST00000619216.1  ENSG00000278267.1                     -
# 4  ENST00000473358.1  ENSG00000243485.5  OTTHUMG00000000959.2
#
#                     ID3              ID4          ID5  \
# 0  OTTHUMT00000362751.1      DDX11L1-202      DDX11L1
# 1  OTTHUMT00000002844.2      DDX11L1-201      DDX11L1
# 2  OTTHUMT00000002839.1       WASH7P-201       WASH7P
# 3                     -    MIR6859-1-201    MIR6859-1
# 4  OTTHUMT00000002840.1  MIR1302-2HG-202  MIR1302-2HG
#
#                                  Type  \
# 0                processed_transcript
# 1  transcribed_unprocessed_pseudogene
# 2              unprocessed_pseudogene
# 3                               miRNA
# 4                             lincRNA
#
#                                                  IDs  counts_SRR6231076  \
# 0  ENST00000456328.2|ENSG00000223972.5|OTTHUMG000...                0.0
# 1  ENST00000450305.2|ENSG00000223972.5|OTTHUMG000...                0.0
# 2  ENST00000488147.1|ENSG00000227232.5|OTTHUMG000...                0.0
# 3  ENST00000619216.1|ENSG00000278267.1|-|-|MIR685...                0.0
# 4  ENST00000473358.1|ENSG00000243485.5|OTTHUMG000...                0.0
#
#    counts_SRR6231077  counts_SRR6231078  counts_SRR6231079  counts_SRR6231080  \
# 0             0.0000                0.0            4.96552                0.0
# 1             0.0000                0.0            0.00000                0.0
# 2            22.4311                0.0           10.25530                0.0
# 3             0.0000                0.0            0.00000                0.0
# 4             0.0000                0.0            0.00000                0.0
#
#    counts_SRR6231081  counts_SRR6231082  counts_SRR6231083  counts_SRR6231084  \
# 0            6.03969       1.086360e-07           38.50470            5.20728
# 1            0.00000       0.000000e+00            0.00000            0.00000
# 2            0.00000       0.000000e+00            5.87389            6.26873
# 3            0.00000       0.000000e+00            0.00000            0.00000
# 4            0.00000       0.000000e+00            0.00000            0.00000
#
#    counts_SRR6231085  counts_SRR6231086  counts_SRR6231087  counts_SRR6231088  \
# 0            0.00000            0.00000            10.3783                0.0
# 1            0.00000            0.00000             0.0000                0.0
# 2            2.31459            1.01631             0.0000                0.0
# 3            0.00000            0.00000             0.0000                0.0
# 4            0.00000            0.00000             0.0000                0.0
#
#    counts_SRR6231089  tpm_SRR6231076  tpm_SRR6231077  tpm_SRR6231078  \
# 0           0.009436             0.0         0.00000             0.0
# 1           0.000000             0.0         0.00000             0.0
# 2           2.594900             0.0         2.58461             0.0
# 3           0.000000             0.0         0.00000             0.0
# 4           0.000000             0.0         0.00000             0.0
#
#    tpm_SRR6231079  tpm_SRR6231080  tpm_SRR6231081  tpm_SRR6231082  \
# 0        0.552004             0.0        0.811906    1.076290e-08
# 1        0.000000             0.0        0.000000    0.000000e+00
# 2        1.418710             0.0        0.000000    0.000000e+00
# 3        0.000000             0.0        0.000000    0.000000e+00
# 4        0.000000             0.0        0.000000    0.000000e+00
#
#    tpm_SRR6231083  tpm_SRR6231084  tpm_SRR6231085  tpm_SRR6231086  \
# 0         4.68295        0.833679         0.00000        0.000000
# 1         0.00000        0.000000         0.00000        0.000000
# 2         0.88899        1.248920         0.32187        0.130272
# 3         0.00000        0.000000         0.00000        0.000000
# 4         0.00000        0.000000         0.00000        0.000000
#
#    tpm_SRR6231087  tpm_SRR6231088  tpm_SRR6231089
# 0        0.934056             0.0        0.000866
# 1        0.000000             0.0        0.000000
# 2        0.000000             0.0        0.296507
# 3        0.000000             0.0        0.000000
# 4        0.000000             0.0        0.000000

# %% [markdown]
# ### Aggregate TPM and counts by gene

# %%
TPM_cols = [col for col in tx_quant.columns if col.startswith('TPM')]
counts_cols = [col for col in tx_quant.columns if col.startswith('counts')]
agg = tx_quant.loc[:,['Tx','Gene']+TPM_cols+counts_cols].groupby('Gene').sum()
agg.head()
# Out:
#                     counts_SRR6231076  counts_SRR6231077  counts_SRR6231078  \
# Gene
# ENSG00000000003.14          32.778680           55.85452         119.701390
# ENSG00000000005.6            0.000000            0.00000           0.000000
# ENSG00000000419.12         588.999600          582.99980        1077.999700
# ENSG00000000457.14         288.547205          333.11850          34.526202
# ENSG00000000460.17           3.206260           75.26510          95.513740
#
#                     counts_SRR6231079  counts_SRR6231080  counts_SRR6231081  \
# Gene
# ENSG00000000003.14          29.571700          69.235300          17.360880
# ENSG00000000005.6            0.000000           0.000000           0.000000
# ENSG00000000419.12         529.000400         803.000000         493.000186
# ENSG00000000457.14         247.394850         224.705900         348.580100
# ENSG00000000460.17         129.515608          75.963721          72.833910
#
#                     counts_SRR6231082  counts_SRR6231083  counts_SRR6231084  \
# Gene
# ENSG00000000003.14          65.004940           18.84840          47.409660
# ENSG00000000005.6            0.000000            0.00000           0.000000
# ENSG00000000419.12         524.000400          503.00050         370.999700
# ENSG00000000457.14         344.524367          118.75980         166.200800
# ENSG00000000460.17          42.178470           56.80857          35.071425
#
#                     counts_SRR6231085  counts_SRR6231086  counts_SRR6231087  \
# Gene
# ENSG00000000003.14            3.21189           45.19161           5.522630
# ENSG00000000005.6             0.00000            0.00000           0.000000
# ENSG00000000419.12          603.99977          609.00000         459.000100
# ENSG00000000457.14          291.47700          322.79310         263.784709
# ENSG00000000460.17          111.77762           42.27115          66.200220
#
#                     counts_SRR6231088  counts_SRR6231089
# Gene
# ENSG00000000003.14            5.95529          78.447600
# ENSG00000000005.6             0.00000           0.000000
# ENSG00000000419.12          672.99950         905.000100
# ENSG00000000457.14          266.74820         320.531600
# ENSG00000000460.17          120.72019         115.744723

# %%
TPM = agg.loc[:,TPM_cols]
TPM.columns = [col.split('_')[1] for col in TPM.columns]
TPM.head().to_csv(os.path.join(QUANTDIR,'kallisto_TPM.csv'))

# %%
counts = agg.loc[:,counts_cols]
counts.columns = [col.split('_')[1] for col in counts.columns]
counts.to_csv(os.path.join(QUANTDIR,'kallisto_counts.csv'))

# %% [markdown]
# After you completed successfully the above steps, you can start to analyze the processed gene expression matrix

# %% [markdown]
# ## References
# ---
#
# 1. Nicolas L Bray, Harold Pimentel, Páll Melsted and Lior Pachter, **Near-optimal probabilistic RNA-seq quantification.** (2016)_Nature Biotechnology_ 34, 525–527 doi:10.1038/nbt.3519
# 2. Ewels **multiQC** https://multiqc.info/
